# %%
import numpy as np

class Drunkard(object):
    
    
    """
    Attributes:
    Time spent drinking every week(T):int
    Age(Y): int
    Drink strength(DS):int
    Quantity of Drinks(QD):int
    Bar Fights lost(BFL):int
    
    Functions:
    age_remaining()
    Calculates the years of life remaining based on attributes
    Teeth()
    estimate of amount of Teeth remaining due to bar fights
    belly volume()
    estimate the volume of the belly in units of Basketballs
    Break teeth()
    break drunkards teeth
   
    
    """
    def _init_(self, T=None,Y=None,DS=None,QD=None,BFL=None):
        self.initiatlise(T=T,Y=Y,DS=DS,QD=QD,BFL=BFL)
        
        return
    def _initialize(self, T=None,Y=None,DS=None,QD=None,BFL=None):
        self.T=np.int16(T)
        self.Y=np.int16(Y)
        self.DS=np.int16(DS)
        self.QD=np.int16(QD)
        self.BFL=np.int16(BFL)
        return
    def age_remaining(self):
        val=self.Y-(self.T+self.DS+3*self.BFL+2*self.QD)
        val=np.int16(val)
        print('Flight is gonna take off at around:',str(val)) 
        
    def teeth(self):
        val=self.BFL
        val=np.int16(val)
        if (self.BFL>10):
            print('Should have used up the denutres too by now!')
        else:   
            print('Dental structure remaining:',str(val))
    def bellyvolume():
        val=2*self.T+2*self.QD/2
        val=np.int16(val)
        if (val>10):
            print('Whale spotted!')
        else:
            print('Things are out of control by about',str(val),'Basketballs')
            
    def breakteeth(self,punches=0):
        if(punches=>10):
            print('There is nothing left, buddy')
        else:
            self.BFL+=punches
            val=self.BFL
        print('He has lost',str(val),'fights leave him alone')
